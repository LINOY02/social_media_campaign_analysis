# %% [markdown]
# # All Data

# %%
users = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='users')
users
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>user_gender</th>
#       <th>user_age</th>
#       <th>country</th>
#       <th>location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>Female</td>
#       <td>24</td>
#       <td>United Kingdom</td>
#       <td>New Mariomouth</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14100000</td>
#       <td>Male</td>
#       <td>21</td>
#       <td>Germany</td>
#       <td>Danielsfort</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34db0</td>
#       <td>Male</td>
#       <td>27</td>
#       <td>Australia</td>
#       <td>Vincentchester</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20d08</td>
#       <td>Female</td>
#       <td>28</td>
#       <td>India</td>
#       <td>Lisaport</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9e830</td>
#       <td>Male</td>
#       <td>28</td>
#       <td>United States</td>
#       <td>Brownmouth</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9995</th>
#       <td>24364</td>
#       <td>Male</td>
#       <td>18</td>
#       <td>United States</td>
#       <td>Curtisside</td>
#     </tr>
#     <tr>
#       <th>9996</th>
#       <td>68b82</td>
#       <td>Male</td>
#       <td>24</td>
#       <td>Mexico</td>
#       <td>Brownland</td>
#     </tr>
#     <tr>
#       <th>9997</th>
#       <td>39f39</td>
#       <td>Male</td>
#       <td>29</td>
#       <td>United States</td>
#       <td>Watersburgh</td>
#     </tr>
#     <tr>
#       <th>9998</th>
#       <td>0b8e7</td>
#       <td>Male</td>
#       <td>31</td>
#       <td>United Kingdom</td>
#       <td>South Kenneth</td>
#     </tr>
#     <tr>
#       <th>9999</th>
#       <td>99e3f</td>
#       <td>Male</td>
#       <td>37</td>
#       <td>Canada</td>
#       <td>New Courtneyview</td>
#     </tr>
#   </tbody>
# </table>
# <p>10000 rows × 5 columns</p>
# </div>

# %%
ads = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='ads')
ads
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>campaign_id</th>
#       <th>ad_platform</th>
#       <th>ad_type</th>
#       <th>target_gender</th>
#       <th>target_age_group</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>Female</td>
#       <td>35-44</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>33</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>20</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>All</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Female</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>24</td>
#       <td>Instagram</td>
#       <td>Image</td>
#       <td>Female</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>195</th>
#       <td>196</td>
#       <td>12</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Male</td>
#       <td>35-44</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>197</td>
#       <td>9</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>All</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>34</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>All</td>
#       <td>35-44</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>15</td>
#       <td>Instagram</td>
#       <td>Video</td>
#       <td>Male</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>200</td>
#       <td>44</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>Male</td>
#       <td>18-24</td>
#     </tr>
#   </tbody>
# </table>
# <p>200 rows × 6 columns</p>
# </div>

# %%
campaigns = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='campaigns')
campaigns
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>campaign_id</th>
#       <th>name</th>
#       <th>start_date</th>
#       <th>end_date</th>
#       <th>total_budget</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Campaign_1_Launch</td>
#       <td>2025-03-25</td>
#       <td>2025-07-23</td>
#       <td>24021.32</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Campaign_2_Launch</td>
#       <td>2025-04-16</td>
#       <td>2025-07-07</td>
#       <td>79342.41</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Campaign_3_Winter</td>
#       <td>2025-05-04</td>
#       <td>2025-06-29</td>
#       <td>14343.25</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>Campaign_4_Summer</td>
#       <td>2025-04-04</td>
#       <td>2025-08-08</td>
#       <td>45326.60</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Campaign_5_Launch</td>
#       <td>2025-05-11</td>
#       <td>2025-08-28</td>
#       <td>68376.69</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Campaign_6_Winter</td>
#       <td>2025-04-21</td>
#       <td>2025-09-13</td>
#       <td>78607.49</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>
pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='interests')
interests
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest_id</th>
#       <th>interest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>art</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>technology</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>food</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>fitness</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>gaming</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>finance</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>lifestyle</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>travel</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>sports</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>health</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>news</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>fashion</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>photography</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
user_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='user_interest')
user_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a2474</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14100000</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14100000</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14100000</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>19929</th>
#       <td>68b82</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>19930</th>
#       <td>39f39</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>19931</th>
#       <td>0b8e7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19932</th>
#       <td>0b8e7</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>19933</th>
#       <td>99e3f</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <p>19934 rows × 2 columns</p>
# </div>

# %%
ad_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='ad_interest')
ad_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>295</th>
#       <td>198</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>296</th>
#       <td>198</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>297</th>
#       <td>199</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>199</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>200</td>
#       <td>13</td>
#     </tr>
#   </tbody>
# </table>
# <p>300 rows × 2 columns</p>
# </div>

# %%
sub_interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='sub_interests')
sub_interests
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest_id</th>
#       <th>interest_id_related</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>3</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>3</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>4</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>4</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>4</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>4</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>5</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>5</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>6</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>6</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>7</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>7</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>7</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>8</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>8</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>9</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>9</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>9</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>10</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>10</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>10</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>10</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>11</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>11</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>11</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>12</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>12</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>13</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>13</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>13</td>
#       <td>2</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Normalize Data

# %%
import pandas as pd
import numpy as np
# !pip install xlrd
# !pip install openpyxl
# Out:
# Requirement already satisfied: xlrd in /opt/python/envs/default_3_11/lib/python3.11/site-packages (2.0.2)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5

# %% [markdown]
# Uplode user table

# %%
users = pd.read_excel('/data/notebook_files/social_media_campaign_analysis_sorce.xlsx', sheet_name='users')
users
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>user_gender</th>
#       <th>user_age</th>
#       <th>country</th>
#       <th>location</th>
#       <th>interests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>Female</td>
#       <td>24</td>
#       <td>United Kingdom</td>
#       <td>New Mariomouth</td>
#       <td>fitness, health</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14100000</td>
#       <td>Male</td>
#       <td>21</td>
#       <td>Germany</td>
#       <td>Danielsfort</td>
#       <td>food, fitness, lifestyle</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34db0</td>
#       <td>Male</td>
#       <td>27</td>
#       <td>Australia</td>
#       <td>Vincentchester</td>
#       <td>fashion, news</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20d08</td>
#       <td>Female</td>
#       <td>28</td>
#       <td>India</td>
#       <td>Lisaport</td>
#       <td>health, news, finance</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9e830</td>
#       <td>Male</td>
#       <td>28</td>
#       <td>United States</td>
#       <td>Brownmouth</td>
#       <td>health, photography, lifestyle</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9995</th>
#       <td>24364</td>
#       <td>Male</td>
#       <td>18</td>
#       <td>United States</td>
#       <td>Curtisside</td>
#       <td>travel, fashion, art</td>
#     </tr>
#     <tr>
#       <th>9996</th>
#       <td>68b82</td>
#       <td>Male</td>
#       <td>24</td>
#       <td>Mexico</td>
#       <td>Brownland</td>
#       <td>finance</td>
#     </tr>
#     <tr>
#       <th>9997</th>
#       <td>39f39</td>
#       <td>Male</td>
#       <td>29</td>
#       <td>United States</td>
#       <td>Watersburgh</td>
#       <td>health</td>
#     </tr>
#     <tr>
#       <th>9998</th>
#       <td>0b8e7</td>
#       <td>Male</td>
#       <td>31</td>
#       <td>United Kingdom</td>
#       <td>South Kenneth</td>
#       <td>art, fashion</td>
#     </tr>
#     <tr>
#       <th>9999</th>
#       <td>99e3f</td>
#       <td>Male</td>
#       <td>37</td>
#       <td>Canada</td>
#       <td>New Courtneyview</td>
#       <td>fitness</td>
#     </tr>
#   </tbody>
# </table>
# <p>10000 rows × 6 columns</p>
# </div>

# %% [markdown]
# Uplode Ads table

# %%
ads = pd.read_excel('/data/notebook_files/social_media_campaign_analysis_sorce.xlsx', sheet_name='ads')
ads
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>campaign_id</th>
#       <th>ad_platform</th>
#       <th>ad_type</th>
#       <th>target_gender</th>
#       <th>target_age_group</th>
#       <th>target_interests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>Female</td>
#       <td>35-44</td>
#       <td>art, technology</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>33</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>25-34</td>
#       <td>travel, photography</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>20</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>All</td>
#       <td>25-34</td>
#       <td>technology</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Female</td>
#       <td>25-34</td>
#       <td>news</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>24</td>
#       <td>Instagram</td>
#       <td>Image</td>
#       <td>Female</td>
#       <td>25-34</td>
#       <td>news</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>195</th>
#       <td>196</td>
#       <td>12</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Male</td>
#       <td>35-44</td>
#       <td>gaming, sports</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>197</td>
#       <td>9</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>All</td>
#       <td>lifestyle, gaming</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>34</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>All</td>
#       <td>35-44</td>
#       <td>fitness, lifestyle</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>15</td>
#       <td>Instagram</td>
#       <td>Video</td>
#       <td>Male</td>
#       <td>25-34</td>
#       <td>art, news</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>200</td>
#       <td>44</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>Male</td>
#       <td>18-24</td>
#       <td>photography</td>
#     </tr>
#   </tbody>
# </table>
# <p>200 rows × 7 columns</p>
# </div>

# %%
def disttinct_intrests(interests):
    res = ", ".join(interests)
    return set(res.split(", "))

# %%
users_interests = disttinct_intrests(users['interests'])
ads_interests = disttinct_intrests(ads['target_interests'])
all_interests = users_interests | ads_interests

interests = pd.DataFrame({'interest_id': range(1, len(all_interests) + 1), 'interest': list(all_interests)})
interests
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest_id</th>
#       <th>interest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>travel</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>news</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>lifestyle</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>sports</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>fashion</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>fitness</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>food</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>health</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>photography</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>finance</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>art</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>technology</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>gaming</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
def create_interests_fact_table(dim_df, interest_df, dim_id, dim_interest, interest_key):
    fact_df = dim_df.assign(**{dim_interest: dim_df[dim_interest].str.split(',')}).explode(dim_interest)
    fact_df[dim_interest] = fact_df[dim_interest].str.strip()
    fact_df = fact_df[[dim_id,dim_interest]].merge(interest_df, left_on=dim_interest, right_on=interest_key)
    fact_df = fact_df.drop([dim_interest, interest_key], axis=1)
    return fact_df

# %%
user_interest_test = create_interests_fact_table(ads, interests, 'ad_id','target_interests', 'interest')
user_interest_test
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>295</th>
#       <td>198</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>296</th>
#       <td>198</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>297</th>
#       <td>199</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>199</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>200</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <p>300 rows × 2 columns</p>
# </div>

# %%
user_interest = (users.assign(interest=users['interests'].str.split(',')).explode('interest'))
user_interest['interest'] = user_interest['interest'].str.strip()
user_interest = user_interest[['user_id', 'interest']]
user_interest = user_interest.merge(interests, on='interest')
user_interest.drop('interest',axis=1,  inplace=True)
user_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a2474</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14100000</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14100000</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14100000</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>19929</th>
#       <td>68b82</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>19930</th>
#       <td>39f39</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>19931</th>
#       <td>0b8e7</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>19932</th>
#       <td>0b8e7</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>19933</th>
#       <td>99e3f</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>
# <p>19934 rows × 2 columns</p>
# </div>

# %%
ad_interest = (ads.assign(target_interests=ads['target_interests'].str.split(',')).explode('target_interests'))

ad_interest['target_interests'] = ad_interest['target_interests'].str.strip()

ad_interest = ad_interest[['ad_id', 'target_interests']]
ad_interest = ad_interest.merge(interests, left_on='target_interests', right_on='interest')
ad_interest.drop(['target_interests','interest'],axis=1,  inplace=True)
ad_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>295</th>
#       <td>198</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>296</th>
#       <td>198</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>297</th>
#       <td>199</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>199</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>200</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <p>300 rows × 2 columns</p>
# </div>

# %%
ad_interest = (ads.assign(target_interests=ads['target_interests'].str.split(',')).explode('target_interests'))

ad_interest['target_interests'] = ad_interest['target_interests'].str.strip()

ad_interest = ad_interest[['ad_id', 'target_interests']]
ad_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>target_interests</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>art</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>technology</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>travel</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>photography</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>technology</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>fitness</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>lifestyle</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>art</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>news</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>200</td>
#       <td>photography</td>
#     </tr>
#   </tbody>
# </table>
# <p>300 rows × 2 columns</p>
# </div>

# %%
ad_interest = ad_interest.merge(interests, left_on='target_interests', right_on='interest')
ad_interest.drop(['target_interests','interest'],axis=1,  inplace=True)
ad_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>295</th>
#       <td>198</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>296</th>
#       <td>198</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>297</th>
#       <td>199</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>199</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>200</td>
#       <td>9</td>
#     </tr>
#   </tbody>
# </table>
# <p>300 rows × 2 columns</p>
# </div>

# %%
pairs = [
    # fashion
    ("fashion", "lifestyle"),
    ("fashion", "art"),

    # news
    ("news", "finance"),
    ("news", "technology"),
    ("news", "sports"),

    # health
    ("health", "sports"),
    ("health", "fitness"),
    ("health", "food"),
    ("health", "lifestyle"),

    # lifestyle
    ("lifestyle", "health"),
    ("lifestyle", "fitness"),
    ("lifestyle", "fashion"),
    ("lifestyle", "travel"),

    # fitness
    ("fitness", "health"),
    ("fitness", "sports"),
    ("fitness", "food"),
    ("fitness", "lifestyle"),

    # technology
    ("technology", "gaming"),
    ("technology", "finance"),
    ("technology", "news"),
    ("technology", "photography"),

    # art
    ("art", "fashion"),
    ("art", "photography"),

    # travel
    ("travel", "photography"),
    ("travel", "lifestyle"),

    # food
    ("food", "lifestyle"),
    ("food", "health"),
    ("food", "fitness"),

    # sports
    ("sports", "fitness"),
    ("sports", "health"),
    ("sports", "news"),
    ("sports", "gaming"),

    # finance
    ("finance", "technology"),
    ("finance", "news"),

    # photography
    ("photography", "travel"),
    ("photography", "art"),
    ("photography", "technology"),

    # gaming
    ("gaming", "technology"),
    ("gaming", "sports"),

]
sub_interests = pd.DataFrame(pairs, columns=["interest", "related_interest"])

sub_interests = (sub_interests.merge(interests, on="interest")
    .rename(columns={"interest_id": "interest_id"}).merge(interests,
        left_on="related_interest", right_on="interest", suffixes=("", "_related"))
    [["interest_id", "interest_id_related"]]
)
sub_interests.sort_values("interest_id", inplace=True)
sub_interests
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest_id</th>
#       <th>interest_id_related</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>24</th>
#       <td>1</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>3</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>3</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>3</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>4</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>4</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>4</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>4</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>5</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>6</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>6</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>6</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>6</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>7</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>7</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>7</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>8</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>8</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>9</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>9</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>9</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>10</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>10</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>11</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>11</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>12</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>12</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>12</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>12</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>13</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>13</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
users.drop('interests', axis=1, inplace=True)
ads.drop('target_interests', axis=1, inplace=True)
campaigns = pd.read_excel('/data/notebook_files/social_media_campaign_analysis_sorce.xlsx', sheet_name='campaigns')
ad_events = pd.read_excel('/data/notebook_files/social_media_campaign_analysis_sorce.xlsx', sheet_name='ad_events')

# %%
tables = [users, campaigns, ads, interests, ad_events, user_interest, ad_interest, sub_interests]
sheet_names = ['users', 'campaigns', 'ads', 'interests', 'ad_events', 'user_interest',
               'ad_interest', 'sub_interests']
path = 'Social_Media_Campaign_Analysis.xlsx'
er =pd.ExcelWriter(path)
for i in range(len(tables)):
    tables[i].to_excel(er, sheet_name=sheet_names[i], index = False)
er.close()

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Uplode Data

# %%
users = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='users')
ads = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='ads')
campaigns = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='campaigns')
ad_events = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='ad_events')
interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='interests')
user_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='user_interest')
ad_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='ad_interest')
sub_interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis.xlsx', sheet_name='sub_interests')

# %% [markdown]
# ### step 1
# Remove duplicate entries for the same user ID from the users table.

# %%
duplicates = users['user_id'].duplicated(keep=False)
duplicate_user_ids = users.loc[duplicates,'user_id'].unique()
users_clean = users.loc[~users['user_id'].isin(duplicate_user_ids)]
users_clean
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>user_gender</th>
#       <th>user_age</th>
#       <th>country</th>
#       <th>location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>Female</td>
#       <td>24</td>
#       <td>United Kingdom</td>
#       <td>New Mariomouth</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14100000</td>
#       <td>Male</td>
#       <td>21</td>
#       <td>Germany</td>
#       <td>Danielsfort</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34db0</td>
#       <td>Male</td>
#       <td>27</td>
#       <td>Australia</td>
#       <td>Vincentchester</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20d08</td>
#       <td>Female</td>
#       <td>28</td>
#       <td>India</td>
#       <td>Lisaport</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9e830</td>
#       <td>Male</td>
#       <td>28</td>
#       <td>United States</td>
#       <td>Brownmouth</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>9995</th>
#       <td>24364</td>
#       <td>Male</td>
#       <td>18</td>
#       <td>United States</td>
#       <td>Curtisside</td>
#     </tr>
#     <tr>
#       <th>9996</th>
#       <td>68b82</td>
#       <td>Male</td>
#       <td>24</td>
#       <td>Mexico</td>
#       <td>Brownland</td>
#     </tr>
#     <tr>
#       <th>9997</th>
#       <td>39f39</td>
#       <td>Male</td>
#       <td>29</td>
#       <td>United States</td>
#       <td>Watersburgh</td>
#     </tr>
#     <tr>
#       <th>9998</th>
#       <td>0b8e7</td>
#       <td>Male</td>
#       <td>31</td>
#       <td>United Kingdom</td>
#       <td>South Kenneth</td>
#     </tr>
#     <tr>
#       <th>9999</th>
#       <td>99e3f</td>
#       <td>Male</td>
#       <td>37</td>
#       <td>Canada</td>
#       <td>New Courtneyview</td>
#     </tr>
#   </tbody>
# </table>
# <p>9893 rows × 5 columns</p>
# </div>

# %%
removed = users.shape[0] -  users_clean.shape[0]
print(f'{removed} records were removed, {removed*100/users.shape[0]}% from the data')
# Out:
# 107 records were removed, 1.07% from the data

# %% [markdown]
# ### step 2
# Remove duplicate entries for the same user ID from the ad_events table.

# %%
ad_events_clean = ad_events.loc[~ad_events['user_id'].isin(duplicate_user_ids)]
ad_events_clean
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>event_id</th>
#       <th>ad_id</th>
#       <th>user_id</th>
#       <th>timestamp</th>
#       <th>event_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>197</td>
#       <td>2359b</td>
#       <td>2025-07-26 00:19:56</td>
#       <td>Like</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>51</td>
#       <td>f9c67</td>
#       <td>2025-06-15 08:28:07</td>
#       <td>Share</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>46</td>
#       <td>5b868</td>
#       <td>2025-06-27 00:40:02</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>166</td>
#       <td>3d440</td>
#       <td>2025-06-05 19:20:45</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>52</td>
#       <td>68f1a</td>
#       <td>2025-07-22 08:30:29</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>399995</th>
#       <td>399996</td>
#       <td>132</td>
#       <td>3cb8c</td>
#       <td>2025-08-01 22:36:54</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>399996</th>
#       <td>399997</td>
#       <td>200</td>
#       <td>fe0e3</td>
#       <td>2025-05-31 14:53:18</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>399997</th>
#       <td>399998</td>
#       <td>2</td>
#       <td>a08c1</td>
#       <td>2025-07-27 13:39:51</td>
#       <td>Click</td>
#     </tr>
#     <tr>
#       <th>399998</th>
#       <td>399999</td>
#       <td>109</td>
#       <td>4f0cf</td>
#       <td>2025-05-16 02:38:23</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>399999</th>
#       <td>400000</td>
#       <td>63</td>
#       <td>2c11d</td>
#       <td>2025-06-15 12:06:28</td>
#       <td>Impression</td>
#     </tr>
#   </tbody>
# </table>
# <p>395756 rows × 5 columns</p>
# </div>

# %%
removed1 = ad_events.shape[0] -  ad_events_clean.shape[0]
print(f'{removed1} records were removed, {removed1*100/ad_events.shape[0]}% from the data')
# Out:
# 4244 records were removed, 1.061% from the data

# %% [markdown]
# ### step 3
# Remove duplicate entries for the same user ID from the `users_interests` table.

# %%
user_interest_clean = user_interest.loc[~user_interest['user_id'].isin(duplicate_user_ids)]
user_interest_clean
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>interest_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>a2474</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14100000</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>14100000</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>14100000</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>19929</th>
#       <td>68b82</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>19930</th>
#       <td>39f39</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>19931</th>
#       <td>0b8e7</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>19932</th>
#       <td>0b8e7</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>19933</th>
#       <td>99e3f</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# <p>19721 rows × 2 columns</p>
# </div>

# %%
removed2 = user_interest.shape[0] -  user_interest_clean.shape[0]
print(f'{removed2} records were removed, {round(removed2*100/user_interest.size,2)}% from the data')
# Out:
# 213 records were removed, 0.53% from the data

# %% [markdown]
# ### step 4
# Remove records from the `ad_events` table with an event time earlier than the campaign start.

# %%
temp = ad_events_clean.merge(ads, on='ad_id')
temp = temp.merge(campaigns, on='campaign_id')
to_remove = temp.loc[temp['timestamp'] < temp['start_date']]['event_id']
ad_events_clean1 = ad_events_clean.loc[~ad_events_clean['event_id'].isin(to_remove)]
ad_events_clean1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>event_id</th>
#       <th>ad_id</th>
#       <th>user_id</th>
#       <th>timestamp</th>
#       <th>event_type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>197</td>
#       <td>2359b</td>
#       <td>2025-07-26 00:19:56</td>
#       <td>Like</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>51</td>
#       <td>f9c67</td>
#       <td>2025-06-15 08:28:07</td>
#       <td>Share</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>46</td>
#       <td>5b868</td>
#       <td>2025-06-27 00:40:02</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>166</td>
#       <td>3d440</td>
#       <td>2025-06-05 19:20:45</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>52</td>
#       <td>68f1a</td>
#       <td>2025-07-22 08:30:29</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>399995</th>
#       <td>399996</td>
#       <td>132</td>
#       <td>3cb8c</td>
#       <td>2025-08-01 22:36:54</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>399996</th>
#       <td>399997</td>
#       <td>200</td>
#       <td>fe0e3</td>
#       <td>2025-05-31 14:53:18</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>399997</th>
#       <td>399998</td>
#       <td>2</td>
#       <td>a08c1</td>
#       <td>2025-07-27 13:39:51</td>
#       <td>Click</td>
#     </tr>
#     <tr>
#       <th>399998</th>
#       <td>399999</td>
#       <td>109</td>
#       <td>4f0cf</td>
#       <td>2025-05-16 02:38:23</td>
#       <td>Impression</td>
#     </tr>
#     <tr>
#       <th>399999</th>
#       <td>400000</td>
#       <td>63</td>
#       <td>2c11d</td>
#       <td>2025-06-15 12:06:28</td>
#       <td>Impression</td>
#     </tr>
#   </tbody>
# </table>
# <p>392936 rows × 5 columns</p>
# </div>

# %%
removed3 = ad_events_clean.shape[0] -  ad_events_clean1.shape[0] 
print(f'{removed3} records were removed, {removed3*100/ad_events.shape[0]}% from the data')
# Out:
# 2820 records were removed, 0.705% from the data

# %%
tables = [users_clean, campaigns, ads, interests, ad_events_clean1, user_interest_clean, ad_interest, sub_interests]
sheet_names = ['users', 'campaigns', 'ads', 'interests', 'ad_events', 'user_interest',
               'ad_interest', 'sub_interests']
path = 'Social_Media_Campaign_Analysis_Clean.xlsx'
er =pd.ExcelWriter(path)
for i in range(len(tables)):
    tables[i].to_excel(er, sheet_name=sheet_names[i], index = False)
er.close()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Uplode Data

# %%
users = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='users')
ads = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='ads')
campaigns = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='campaigns')
ad_events = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='ad_events')
interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='interests')
user_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='user_interest')
ad_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='ad_interest')
sub_interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean.xlsx', sheet_name='sub_interests')

# %% [markdown]
# Splitting Age Ranges in the Ads Table

# %%
def extract_age(col_values, min_a, max_a):
    min_age_col,max_age_col = [], []

    for i in col_values:
        if i == 'All':
            min_age_col.append(min_a)
            max_age_col.append(max_a)
        else:
            min_age_col.append(int(i[:2]))
            max_age_col.append(int(i[-2:]))
    return min_age_col, max_age_col

min_age, max_age = min(users['user_age']), max(users['user_age'])
min_age_col, max_age_col = extract_age(ads['target_age_group'].values, min_age, max_age)
ads['min_age'] = min_age_col
ads['max_age'] = max_age_col
ads
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>campaign_id</th>
#       <th>ad_platform</th>
#       <th>ad_type</th>
#       <th>target_gender</th>
#       <th>target_age_group</th>
#       <th>min_age</th>
#       <th>max_age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>Female</td>
#       <td>35-44</td>
#       <td>35</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>33</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>20</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>All</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Female</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>24</td>
#       <td>Instagram</td>
#       <td>Image</td>
#       <td>Female</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>195</th>
#       <td>196</td>
#       <td>12</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Male</td>
#       <td>35-44</td>
#       <td>35</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>197</td>
#       <td>9</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>All</td>
#       <td>16</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>34</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>All</td>
#       <td>35-44</td>
#       <td>35</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>15</td>
#       <td>Instagram</td>
#       <td>Video</td>
#       <td>Male</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>200</td>
#       <td>44</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>Male</td>
#       <td>18-24</td>
#       <td>18</td>
#       <td>24</td>
#     </tr>
#   </tbody>
# </table>
# <p>200 rows × 8 columns</p>
# </div>

# %% [markdown]
# Categorizing Ads and Users into Age Groups

# %%
label_dict = {'All':'All', '18-24':'Young', '25-34':'Young Adults', '35-44':'Adults'}
ads['age_group_label'] = ads['target_age_group'].map(label_dict)
ads
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>campaign_id</th>
#       <th>ad_platform</th>
#       <th>ad_type</th>
#       <th>target_gender</th>
#       <th>target_age_group</th>
#       <th>min_age</th>
#       <th>max_age</th>
#       <th>age_group_label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>Female</td>
#       <td>35-44</td>
#       <td>35</td>
#       <td>44</td>
#       <td>Adults</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>33</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#       <td>Young Adults</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>20</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>All</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#       <td>Young Adults</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>28</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Female</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#       <td>Young Adults</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>24</td>
#       <td>Instagram</td>
#       <td>Image</td>
#       <td>Female</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#       <td>Young Adults</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>195</th>
#       <td>196</td>
#       <td>12</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>Male</td>
#       <td>35-44</td>
#       <td>35</td>
#       <td>44</td>
#       <td>Adults</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>197</td>
#       <td>9</td>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>All</td>
#       <td>All</td>
#       <td>16</td>
#       <td>65</td>
#       <td>All</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>34</td>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>All</td>
#       <td>35-44</td>
#       <td>35</td>
#       <td>44</td>
#       <td>Adults</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>15</td>
#       <td>Instagram</td>
#       <td>Video</td>
#       <td>Male</td>
#       <td>25-34</td>
#       <td>25</td>
#       <td>34</td>
#       <td>Young Adults</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>200</td>
#       <td>44</td>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>Male</td>
#       <td>18-24</td>
#       <td>18</td>
#       <td>24</td>
#       <td>Young</td>
#     </tr>
#   </tbody>
# </table>
# <p>200 rows × 9 columns</p>
# </div>

# %% [markdown]
# Categorizing Users into Age Groups

# %%
bins = [16, 25, 35, 45, 66]
labels = ['Young', 'Young Adults', 'Adults', 'Elderly']
users['age_label'] = pd.cut(users['user_age'],bins=bins,labels=labels,right=False,include_lowest=True)
users['age_range'] = pd.cut(users['user_age'],bins=bins,right=False,include_lowest=True).apply(lambda x: f"{int(x.left)}-{int(x.right)-1}")
users
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_id</th>
#       <th>user_gender</th>
#       <th>user_age</th>
#       <th>country</th>
#       <th>location</th>
#       <th>age_label</th>
#       <th>age_range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>a2474</td>
#       <td>Female</td>
#       <td>24</td>
#       <td>United Kingdom</td>
#       <td>New Mariomouth</td>
#       <td>Young</td>
#       <td>16-24</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>14100000</td>
#       <td>Male</td>
#       <td>21</td>
#       <td>Germany</td>
#       <td>Danielsfort</td>
#       <td>Young</td>
#       <td>16-24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34db0</td>
#       <td>Male</td>
#       <td>27</td>
#       <td>Australia</td>
#       <td>Vincentchester</td>
#       <td>Young Adults</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>20d08</td>
#       <td>Female</td>
#       <td>28</td>
#       <td>India</td>
#       <td>Lisaport</td>
#       <td>Young Adults</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>9e830</td>
#       <td>Male</td>
#       <td>28</td>
#       <td>United States</td>
#       <td>Brownmouth</td>
#       <td>Young Adults</td>
#       <td>25-34</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th
td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>40</td>
#       <td>Campaign_40_Summer</td>
#       <td>2025-03-04</td>
#       <td>2025-04-20</td>
#       <td>53936.41</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>41</td>
#       <td>Campaign_41_Winter</td>
#       <td>2025-04-02</td>
#       <td>2025-06-12</td>
#       <td>85220.35</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>41</t

# %% [markdown]
# Extracting Date and Time Features

# %%
ad_events['Day_Of_Week'] = ad_events['timestamp'].dt.day_name()
ad_events['Is_weekend'] = ad_events['timestamp'].dt.dayofweek >= 4
ad_events['Hour'] = ad_events['timestamp'].dt.hour
ad_events
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>event_id</th>
#       <th>ad_id</th>
#       <th>user_id</th>
#       <th>timestamp</th>
#       <th>event_type</th>
#       <th>Day_Of_Week</th>
#       <th>Is_weekend</th>
#       <th>Hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>197</td>
#       <td>2359b</td>
#       <td>2025-07-26 00:19:56</td>
#       <td>Like</td>
#       <td>Saturday</td>
#       <td>True</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>51</td>
#       <td>f9c67</td>
#       <td>2025-06-15 08:28:07</td>
#       <td>Share</td>
#       <td>Sunday</td>
#       <td>True</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>46</td>
#       <td>5b868</td>
#       <td>2025-06-27 00:40:02</td>
#       <td>Impression</td>
#       <td>Friday</td>
#       <td>True</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>166</td>
#       <td>3d440</td>
#       <td>2025-06-05 19:20:45</td>
#       <td>Impression</td>
#       <td>Thursday</td>
#       <td>False</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>52</td>
#       <td>68f1a</td>
#       <td>2025-07-22 08:30:29</td>
#       <td>Impression</td>
#       <td>Tuesday</td>
#       <td>False</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>392931</th>
#       <td>399996</td>
#       <td>132</td>
#       <td>3cb8c</td>
#       <td>2025-08-01 22:36:54</td>
#       <td>Impression</td>
#       <td>Friday</td>
#       <td>True</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>392932</th>
#       <td>399997</td>
#       <td>200</td>
#       <td>fe0e3</td>
#       <td>2025-05-31 14:53:18</td>
#       <td>Impression</td>
#       <td>Saturday</td>
#       <td>True</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>392933</th>
#       <td>399998</td>
#       <td>2</td>
#       <td>a08c1</td>
#       <td>2025-07-27 13:39:51</td>
#       <td>Click</td>
#       <td>Sunday</td>
#       <td>True</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>392934</th>
#       <td>399999</td>
#       <td>109</td>
#       <td>4f0cf</td>
#       <td>2025-05-16 02:38:23</td>
#       <td>Impression</td>
#       <td>Friday</td>
#       <td>True</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>392935</th>
#       <td>400000</td>
#       <td>63</td>
#       <td>2c11d</td>
#       <td>2025-06-15 12:06:28</td>
#       <td>Impression</td>
#       <td>Sunday</td>
#       <td>True</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# <p>392936 rows × 8 columns</p>
# </div>

# %%
from datetime import time

def get_day_part_from_time(t, day_part_dict):
    h = t
    for (start, end), label in day_part_dict.items():
        if start <= end:
            if start <= h <= end:
                return label
        else:
            if h >= start or h <= end:
                return label
    return None

# %%
day_part = {(6,11):'morning',(12,16):'noon', (17,22):'evening',(23,5):'night'}
ad_events['day_part'] = ad_events['Hour'].apply(
    lambda h: get_day_part_from_time(h, day_part)
)
ad_events
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>event_id</th>
#       <th>ad_id</th>
#       <th>user_id</th>
#       <th>timestamp</th>
#       <th>event_type</th>
#       <th>Day_Of_Week</th>
#       <th>Is_weekend</th>
#       <th>Hour</th>
#       <th>day_part</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>197</td>
#       <td>2359b</td>
#       <td>2025-07-26 00:19:56</td>
#       <td>Like</td>
#       <td>Saturday</td>
#       <td>True</td>
#       <td>0</td>
#       <td>night</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>51</td>
#       <td>f9c67</td>
#       <td>2025-06-15 08:28:07</td>
#       <td>Share</td>
#       <td>Sunday</td>
#       <td>True</td>
#       <td>8</td>
#       <td>morning</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>46</td>
#       <td>5b868</td>
#       <td>2025-06-27 00:40:02</td>
#       <td>Impression</td>
#       <td>Friday</td>
#       <td>True</td>
#       <td>0</td>
#       <td>night</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>166</td>
#       <td>3d440</td>
#       <td>2025-06-05 19:20:45</td>
#       <td>Impression</td>
#       <td>Thursday</td>
#       <td>False</td>
#       <td>19</td>
#       <td>evening</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>52</td>
#       <td>68f1a</td>
#       <td>2025-07-22 08:30:29</td>
#       <td>Impression</td>
#       <td>Tuesday</td>
#       <td>False</td>
#       <td>8</td>
#       <td>morning</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>392931</th>
#       <td>399996</td>
#       <td>132</td>
#       <td>3cb8c</td>
#       <td>2025-08-01 22:36:54</td>
#       <td>Impression</td>
#       <td>Friday</td>
#       <td>True</td>
#       <td>22</td>
#       <td>evening</td>
#     </tr>
#     <tr>
#       <th>392932</th>
#       <td>399997</td>
#       <td>200</td>
#       <td>fe0e3</td>
#       <td>2025-05-31 14:53:18</td>
#       <td>Impression</td>
#       <td>Saturday</td>
#       <td>True</td>
#       <td>14</td>
#       <td>noon</td>
#     </tr>
#     <tr>
#       <th>392933</th>
#       <td>399998</td>
#       <td>2</td>
#       <td>a08c1</td>
#       <td>2025-07-27 13:39:51</td>
#       <td>Click</td>
#       <td>Sunday</td>
#       <td>True</td>
#       <td>13</td>
#       <td>noon</td>
#     </tr>
#     <tr>
#       <th>392934</th>
#       <td>399999</td>
#       <td>109</td>
#       <td>4f0cf</td>
#       <td>2025-05-16 02:38:23</td>
#       <td>Impression</td>
#       <td>Friday</td>
#       <td>True</td>
#       <td>2</td>
#       <td>night</td>
#     </tr>
#     <tr>
#       <th>392935</th>
#       <td>400000</td>
#       <td>63</td>
#       <td>2c11d</td>
#       <td>2025-06-15 12:06:28</td>
#       <td>Impression</td>
#       <td>Sunday</td>
#       <td>True</td>
#       <td>12</td>
#       <td>noon</td>
#     </tr>
#   </tbody>
# </table>
# <p>392936 rows × 9 columns</p>
# </div>

# %%
tables = [users, campaigns, ads, interests, ad_events, user_interest, ad_interest, sub_interests]
sheet_names = ['users', 'campaigns', 'ads', 'interests', 'ad_events', 'user_interest',
               'ad_interest', 'sub_interests']
path = 'Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx'
er =pd.ExcelWriter(path)
for i in range(len(tables)):
    tables[i].to_excel(er, sheet_name=sheet_names[i], index = False)
er.close()

# %% [markdown]
# # KPI Calculations

# %%
users = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='users')
ads = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='ads')
campaigns = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='campaigns')
ad_events = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='ad_events')
interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='interests')
user_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='user_interest')
ad_interest = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='ad_interest')
sub_interests = pd.read_excel('/data/notebook_files/Social_Media_Campaign_Analysis_Clean&feature_engineered.xlsx', sheet_name='sub_interests')

# %% [markdown]
# #### Total Interactions

# %%
total_interactions = ad_events.shape[0]
print("Total events: " + str(total_interactions))
total_users = users.shape[0]
print("Total users: " + str(total_users))
total_ads = ads.shape[0]
print("Total ads: " + str(total_ads))
total_campaigns = campaigns.shape[0]
print("Total campaigns: " + str(total_campaigns))
# Out:
# Total events: 392936
# Total users: 9893
# Total ads: 200
# Total campaigns: 50

# %% [markdown]
# #### Interactions by Campaign

# %%
interactions_by_campaign = (ad_events.merge(ads[['ad_id', 'campaign_id']], on='ad_id')
    .groupby('campaign_id').size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_campaign
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>campaign_id</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>18</th>
#       <td>20</td>
#       <td>15871</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>42</td>
#       <td>15837</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>24</td>
#       <td>15831</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>17</td>
#       <td>15798</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>38</td>
#       <td>15710</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>33</td>
#       <td>14016</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>29</td>
#       <td>12453</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>12046</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>12001</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>47</td>
#       <td>11963</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>11882</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>37</td>
#       <td>11855</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>34</td>
#       <td>11571</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>25</td>
#       <td>10080</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>22</td>
#       <td>10013</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>9932</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>46</td>
#       <td>9907</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>9801</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>32</td>
#       <td>8035</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>30</td>
#       <td>7921</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>40</td>
#       <td>7867</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>21</td>
#       <td>7844</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>7812</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>7739</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>44</td>
#       <td>7324</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>6081</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>39</td>
#       <td>6021</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>41</td>
#       <td>5988</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>28</td>
#       <td>5970</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>5954</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>26</td>
#       <td>5945</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>5939</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>31</td>
#       <td>5871</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>5866</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>18</td>
#       <td>5864</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5860</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>5770</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>23</td>
#       <td>5689</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>4002</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>36</td>
#       <td>3978</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>19</td>
#       <td>3975</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>49</td>
#       <td>3972</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>48</td>
#       <td>3912</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>27</td>
#       <td>3899</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>45</td>
#       <td>3842</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>3840</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>50</td>
#       <td>1981</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>35</td>
#       <td>1608</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Interactions by Ad

# %%
interactions_by_ad = (ad_events.groupby('ad_id').size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_ad
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>191</th>
#       <td>192</td>
#       <td>2091</td>
#     </tr>
#     <tr>
#       <th>69</th>
#       <td>70</td>
#       <td>2089</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>102</td>
#       <td>2072</td>
#     </tr>
#     <tr>
#       <th>100</th>
#       <td>101</td>
#       <td>2070</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>66</td>
#       <td>2070</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>162</th>
#       <td>163</td>
#       <td>1778</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>54</td>
#       <td>1767</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>83</td>
#       <td>1760</td>
#     </tr>
#     <tr>
#       <th>80</th>
#       <td>81</td>
#       <td>1727</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>43</td>
#       <td>1608</td>
#     </tr>
#   </tbody>
# </table>
# <p>200 rows × 2 columns</p>
# </div>

# %% [markdown]
# #### Interactions by Platform

# %%
interactions_by_platform = (ad_events.merge(ads[['ad_id', 'ad_platform']], on='ad_id')
    .groupby('ad_platform').size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_platform
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_platform</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Facebook</td>
#       <td>250274</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Instagram</td>
#       <td>142662</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Interactions by type

# %%
interactions_by_type = (ad_events.merge(ads[['ad_id', 'ad_platform', 'ad_type']], on='ad_id')
    .groupby(['ad_platform', 'ad_type']).size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_type
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_platform</th>
#       <th>ad_type</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Facebook</td>
#       <td>Stories</td>
#       <td>83378</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Facebook</td>
#       <td>Image</td>
#       <td>59039</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Facebook</td>
#       <td>Carousel</td>
#       <td>55311</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Facebook</td>
#       <td>Video</td>
#       <td>52546</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Instagram</td>
#       <td>Carousel</td>
#       <td>44688</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Instagram</td>
#       <td>Image</td>
#       <td>43032</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Instagram</td>
#       <td>Stories</td>
#       <td>42977</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>
td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>49</td>
#       <td>28962.34</td>
#       <td>3972</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>34</td>
#       <td>26104.30</td>
#       <td>11571</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>23</td>
#       <td>26001.67</td>
#       <td>5689</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>24021.32</td>
#       <td>5860</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>21855.42</td>
#       <td>12046</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>29</td>
#       <td>19773.66</td>
#       <td>12453</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>19669.27</td>
#       <td>7739</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>44</td>
#       <td>15914.87</td>
#       <td>7324</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>14343.25</td>
#       <td>7812</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>48</td>
#       <td>13842.07</td>
#       <td>3912</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>27</td>
#       <td>12986.30</td>
#       <td>3899</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>42</td>
#       <td>7918.04</td>
#       <td>15837</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Interactions by Age Group (Users)

# %%
interactions_by_age_group = (ad_events.merge(users[['user_id', 'age_label', 'age_range']], on='user_id')
    .groupby(['age_label', 'age_range']).size().reset_index(name='interaction_count')
    .sort_values('age_range', ascending=True)
)
interactions_by_age_group
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age_label</th>
#       <th>age_range</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Young</td>
#       <td>16-24</td>
#       <td>157534</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Young Adults</td>
#       <td>25-34</td>
#       <td>162463</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Adults</td>
#       <td>35-44</td>
#       <td>56802</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Elderly</td>
#       <td>45-65</td>
#       <td>16137</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Targeting Match – User Age vs Ad Age

# %%
targeting_match = (ad_events.merge(users[['user_id', 'age_label']], on='user_id')
    .merge(ads[['ad_id', 'age_group_label']], on='ad_id').groupby(['age_group_label', 'age_label'])
    .size().reset_index(name='interaction_count')
)
total_per_ad_age = targeting_match.groupby('age_group_label')['interaction_count'].transform('sum')
targeting_match['interaction_ratio'] = ((targeting_match['interaction_count'] / total_per_ad_age) * 100).round(2)
targeting_match.rename(columns={'age_label': 'user_age', 'age_group_label': 'ad_age'})
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_age</th>
#       <th>user_age</th>
#       <th>interaction_count</th>
#       <th>interaction_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Adults</td>
#       <td>Adults</td>
#       <td>15328</td>
#       <td>14.47</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Adults</td>
#       <td>Elderly</td>
#       <td>4357</td>
#       <td>4.11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Adults</td>
#       <td>Young</td>
#       <td>42416</td>
#       <td>40.04</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Adults</td>
#       <td>Young Adults</td>
#       <td>43829</td>
#       <td>41.38</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>All</td>
#       <td>Adults</td>
#       <td>13090</td>
#       <td>14.47</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>All</td>
#       <td>Elderly</td>
#       <td>3655</td>
#       <td>4.04</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>All</td>
#       <td>Young</td>
#       <td>36360</td>
#       <td>40.20</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>All</td>
#       <td>Young Adults</td>
#       <td>37347</td>
#       <td>41.29</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Young</td>
#       <td>Adults</td>
#       <td>15387</td>
#       <td>14.46</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Young</td>
#       <td>Elderly</td>
#       <td>4471</td>
#       <td>4.20</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Young</td>
#       <td>Young</td>
#       <td>42775</td>
#       <td>40.20</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Young</td>
#       <td>Young Adults</td>
#       <td>43781</td>
#       <td>41.14</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Young Adults</td>
#       <td>Adults</td>
#       <td>12997</td>
#       <td>14.42</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Young Adults</td>
#       <td>Elderly</td>
#       <td>3654</td>
#       <td>4.05</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Young Adults</td>
#       <td>Young</td>
#       <td>35983</td>
#       <td>39.92</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Young Adults</td>
#       <td>Young Adults</td>
#       <td>37506</td>
#       <td>41.61</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Interactions by Gender

# %%
interactions_by_gender = (ad_events.merge(users[['user_id', 'user_gender']], on='user_id')
    .groupby('user_gender').size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_gender
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user_gender</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Male</td>
#       <td>217759</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Female</td>
#       <td>135374</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Other</td>
#       <td>39803</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Targeting Match – User Gender vs Ad Gender Target

# %%
targeting_match1 = (ad_events.merge(users[['user_id', 'user_gender']], on='user_id')
    .merge(ads[['ad_id', 'target_gender']], on='ad_id').groupby(['target_gender', 'user_gender'])
    .size().reset_index(name='interaction_count')
)
total_per_ad_gender = targeting_match1.groupby('target_gender')['interaction_count'].transform('sum')
targeting_match1['interaction_ratio'] = ((targeting_match1['interaction_count'] / total_per_ad_gender) * 100).round(2)
targeting_match1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target_gender</th>
#       <th>user_gender</th>
#       <th>interaction_count</th>
#       <th>interaction_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>All</td>
#       <td>Female</td>
#       <td>48007</td>
#       <td>34.51</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>All</td>
#       <td>Male</td>
#       <td>77022</td>
#       <td>55.37</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>All</td>
#       <td>Other</td>
#       <td>14064</td>
#       <td>10.11</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Female</td>
#       <td>Female</td>
#       <td>56229</td>
#       <td>34.45</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Female</td>
#       <td>Male</td>
#       <td>90505</td>
#       <td>55.45</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Female</td>
#       <td>Other</td>
#       <td>16481</td>
#       <td>10.10</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Male</td>
#       <td>Female</td>
#       <td>31138</td>
#       <td>34.36</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Male</td>
#       <td>Male</td>
#       <td>50232</td>
#       <td>55.43</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Male</td>
#       <td>Other</td>
#       <td>9258</td>
#       <td>10.22</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Interactions by Interest

# %%
interactions_by_interest = (ad_events.merge(ad_interest, on='ad_id')
    .merge(interests, on='interest_id').groupby('interest')
    .size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_interest
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>fitness</td>
#       <td>61914</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>technology</td>
#       <td>61311</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>travel</td>
#       <td>61101</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>art</td>
#       <td>60980</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>gaming</td>
#       <td>60734</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>lifestyle</td>
#       <td>60692</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>fashion</td>
#       <td>60257</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>sports</td>
#       <td>59889</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>health</td>
#       <td>59868</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>food</td>
#       <td>59282</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>news</td>
#       <td>59177</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>finance</td>
#       <td>58911</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>photography</td>
#       <td>58539</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Ad Interest Match: Exact, Family, No Match

# %%
temp = ad_events.merge(users[['user_id']], on='user_id')
temp = temp.merge(ads[['ad_id']], on='ad_id')
temp = temp.merge(user_interest, on='user_id')
temp = temp.merge(ad_interest, on='ad_id', suffixes=('_user', '_ad')) 
temp = temp.merge(sub_interests, left_on='interest_id_user', right_on='interest_id_related', how='left')
temp['exact_match'] = temp['interest_id_user'] == temp['interest_id_ad']
temp['family_match'] = (~temp['exact_match']) & (temp['interest_id_ad'].notnull()) & (temp['interest_id_related'].notnull())
temp['no_match'] = (~temp['exact_match']) & (~temp['family_match'])

interest_match_summary = temp.groupby('ad_id').agg(
    exact_match_count=('exact_match', 'sum'),
    family_match_count=('family_match', 'sum'),
    no_match_count=('no_match', 'sum')
).reset_index()

interest_match_summary
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ad_id</th>
#       <th>exact_match_count</th>
#       <th>family_match_count</th>
#       <th>no_match_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1922</td>
#       <td>22482</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1433</td>
#       <td>22635</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1288</td>
#       <td>10575</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>903</td>
#       <td>11290</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>981</td>
#       <td>11093</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>195</th>
#       <td>196</td>
#       <td>1858</td>
#       <td>21752</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>196</th>
#       <td>197</td>
#       <td>2162</td>
#       <td>21564</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>197</th>
#       <td>198</td>
#       <td>2771</td>
#       <td>19827</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>198</th>
#       <td>199</td>
#       <td>1526</td>
#       <td>21744</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>199</th>
#       <td>200</td>
#       <td>846</td>
#       <td>9993</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>200 rows × 4 columns</p>
# </div>

# %% [markdown]
# #### User Interest Distribution by Age

# %%
age_interest_count = (user_interest.merge(users[['user_id', 'age_label']], on='user_id')
    .merge(interests[['interest_id', 'interest']], on='interest_id')
    .groupby(['interest', 'age_label'])['user_id'].nunique()
    .reset_index(name='unique_user_count')
)
age_interest_count
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest</th>
#       <th>age_label</th>
#       <th>unique_user_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>art</td>
#       <td>Adults</td>
#       <td>238</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>art</td>
#       <td>Elderly</td>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>art</td>
#       <td>Young</td>
#       <td>606</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>art</td>
#       <td>Young Adults</td>
#       <td>629</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>fashion</td>
#       <td>Adults</td>
#       <td>217</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>fashion</td>
#       <td>Elderly</td>
#       <td>63</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>fashion</td>
#       <td>Young</td>
#       <td>613</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>fashion</td>
#       <td>Young Adults</td>
#       <td>631</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>finance</td>
#       <td>Adults</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>finance</td>
#       <td>Elderly</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>finance</td>
#       <td>Young</td>
#       <td>610</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>finance</td>
#       <td>Young Adults</td>
#       <td>610</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>fitness</td>
#       <td>Adults</td>
#       <td>236</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>fitness</td>
#       <td>Elderly</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>fitness</td>
#       <td>Young</td>
#       <td>649</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>fitness</td>
#       <td>Young Adults</td>
#       <td>605</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>food</td>
#       <td>Adults</td>
#       <td>243</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>food</td>
#       <td>Elderly</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>food</td>
#       <td>Young</td>
#       <td>589</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>food</td>
#       <td>Young Adults</td>
#       <td>601</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>gaming</td>
#       <td>Adults</td>
#       <td>226</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>gaming</td>
#       <td>Elderly</td>
#       <td>57</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>gaming</td>
#       <td>Young</td>
#       <td>611</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>gaming</td>
#       <td>Young Adults</td>
#       <td>637</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>health</td>
#       <td>Adults</td>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>health</td>
#       <td>Elderly</td>
#       <td>67</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>health</td>
#       <td>Young</td>
#       <td>573</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>health</td>
#       <td>Young Adults</td>
#       <td>673</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>lifestyle</td>
#       <td>Adults</td>
#       <td>207</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>lifestyle</td>
#       <td>Elderly</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>lifestyle</td>
#       <td>Young</td>
#       <td>633</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>lifestyle</td>
#       <td>Young Adults</td>
#       <td>627</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>news</td>
#       <td>Adults</td>
#       <td>221</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>news</td>
#       <td>Elderly</td>
#       <td>55</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>news</td>
#       <td>Young</td>
#       <td>605</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>news</td>
#       <td>Young Adults</td>
#       <td>614</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>photography</td>
#       <td>Adults</td>
#       <td>205</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>photography</td>
#       <td>Elderly</td>
#       <td>74</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>photography</td>
#       <td>Young</td>
#       <td>561</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>photography</td>
#       <td>Young Adults</td>
#       <td>629</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>sports</td>
#       <td>Adults</td>
#       <td>219</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>sports</td>
#       <td>Elderly</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>sports</td>
#       <td>Young</td>
#       <td>634</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>sports</td>
#       <td>Young Adults</td>
#       <td>605</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>technology</td>
#       <td>Adults</td>
#       <td>188</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>technology</td>
#       <td>Elderly</td>
#       <td>64</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>technology</td>
#       <td>Young</td>
#       <td>644</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>technology</td>
#       <td>Young Adults</td>
#       <td>656</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>travel</td>
#       <td>Adults</td>
#       <td>240</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>travel</td>
#       <td>Elderly</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>travel</td>
#       <td>Young</td>
#       <td>626</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>travel</td>
#       <td>Young Adults</td>
#       <td>593</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### User Interest Distribution by Gender

# %%
age_interest_count1 = (user_interest.merge(users[['user_id', 'user_gender']], on='user_id')
    .merge(interests[['interest_id', 'interest']], on='interest_id')
    .groupby(['interest', 'user_gender'])['user_id'].nunique()
    .reset_index(name='unique_user_count')
)
age_interest_count1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest</th>
#       <th>user_gender</th>
#       <th>unique_user_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>art</td>
#       <td>Female</td>
#       <td>511</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>art</td>
#       <td>Male</td>
#       <td>881</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>art</td>
#       <td>Other</td>
#       <td>141</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>fashion</td>
#       <td>Female</td>
#       <td>512</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>fashion</td>
#       <td>Male</td>
#       <td>843</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>fashion</td>
#       <td>Other</td>
#       <td>169</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>finance</td>
#       <td>Female</td>
#       <td>502</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>finance</td>
#       <td>Male</td>
#       <td>822</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>finance</td>
#       <td>Other</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>fitness</td>
#       <td>Female</td>
#       <td>553</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>fitness</td>
#       <td>Male</td>
#       <td>846</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>fitness</td>
#       <td>Other</td>
#       <td>167</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>food</td>
#       <td>Female</td>
#       <td>541</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>food</td>
#       <td>Male</td>
#       <td>807</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>food</td>
#       <td>Other</td>
#       <td>146</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>gaming</td>
#       <td>Female</td>
#       <td>543</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>gaming</td>
#       <td>Male</td>
#       <td>837</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>gaming</td>
#       <td>Other</td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>health</td>
#       <td>Female</td>
#       <td>517</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>health</td>
#       <td>Male</td>
#       <td>838</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>health</td>
#       <td>Other</td>
#       <td>159</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>lifestyle</td>
#       <td>Female</td>
#       <td>522</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>lifestyle</td>
#       <td>Male</td>
#       <td>845</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>lifestyle</td>
#       <td>Other</td>
#       <td>161</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>news</td>
#       <td>Female</td>
#       <td>491</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>news</td>
#       <td>Male</td>
#       <td>849</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>news</td>
#       <td>Other</td>
#       <td>155</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>photography</td>
#       <td>Female</td>
#       <td>524</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>photography</td>
#       <td>Male</td>
#       <td>813</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>photography</td>
#       <td>Other</td>
#       <td>132</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>sports</td>
#       <td>Female</td>
#       <td>511</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>sports</td>
#       <td>Male</td>
#       <td>839</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>sports</td>
#       <td>Other</td>
#       <td>157</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>technology</td>
#       <td>Female</td>
#       <td>533</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>technology</td>
#       <td>Male</td>
#       <td>866</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>technology</td>
#       <td>Other</td>
#       <td>153</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>travel</td>
#       <td>Female</td>
#       <td>550</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>travel</td>
#       <td>Male</td>
#       <td>827</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>travel</td>
#       <td>Other</td>
#       <td>152</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Event count per interest and platform

# %%
event_order = {'Impression': 1, 'Like': 2, 'Comment': 3, 'Share': 4, 'Click': 5, 'Purchase': 6}
interest_platform_events = (ad_events.merge(ads[['ad_id', 'ad_platform']], on='ad_id')
    .merge(ad_interest, on='ad_id').merge(interests[['interest_id', 'interest']], on='interest_id')
    .groupby(['interest', 'ad_platform', 'event_type'])['event_id']
    .count().reset_index(name='event_count'))

interest_platform_events = interest_platform_events.sort_values(
    by=['interest', 'ad_platform', 'event_type'],
    key=lambda col: col.map(event_order) if col.name == 'event_type' else col)

interest_platform_events
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>interest</th>
#       <th>ad_platform</th>
#       <th>event_type</th>
#       <th>event_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>art</td>
#       <td>Facebook</td>
#       <td>Impression</td>
#       <td>16713</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>art</td>
#       <td>Facebook</td>
#       <td>Like</td>
#       <td>604</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>art</td>
#       <td>Facebook</td>
#       <td>Comment</td>
#       <td>211</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>art</td>
#       <td>Facebook</td>
#       <td>Share</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>art</td>
#       <td>Facebook</td>
#       <td>Click</td>
#       <td>1966</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>153</th>
#       <td>travel</td>
#       <td>Instagram</td>
#       <td>Like</td>
#       <td>582</td>
#     </tr>
#     <tr>
#       <th>151</th>
#       <td>travel</td>
#       <td>Instagram</td>
#       <td>Comment</td>
#       <td>194</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>travel</td>
#       <td>Instagram</td>
#       <td>Share</td>
#       <td>96</td>
#     </tr>
#     <tr>
#       <th>150</th>
#       <td>travel</td>
#       <td>Instagram</td>
#       <td>Click</td>
#       <td>1961</td>
#     </tr>
#     <tr>
#       <th>154</th>
#       <td>travel</td>
#       <td>Instagram</td>
#       <td>Purchase</td>
#       <td>83</td>
#     </tr>
#   </tbody>
# </table>
# <p>156 rows × 4 columns</p>
# </div>

# %% [markdown]
# #### Time-Based Engagement

# %%
interactions_by_day = (ad_events.groupby('Day_Of_Week').size()
    .reset_index(name='interaction_count')
)
interactions_by_day
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Day_Of_Week</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Friday</td>
#       <td>56253</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Monday</td>
#       <td>56388</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Saturday</td>
#       <td>56079</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Sunday</td>
#       <td>56078</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Thursday</td>
#       <td>55830</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Tuesday</td>
#       <td>56205</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Wednesday</td>
#       <td>56103</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
interactions_by_hour = (ad_events.groupby('Hour').size()
    .reset_index(name='interaction_count')
)
interactions_by_hour
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Hour</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>16335</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>16358</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>16592</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>16236</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>16311</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>5</td>
#       <td>16354</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>6</td>
#       <td>16295</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>7</td>
#       <td>16180</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>8</td>
#       <td>16627</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>9</td>
#       <td>16251</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>10</td>
#       <td>16328</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>11</td>
#       <td>16488</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>12</td>
#       <td>16487</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>13</td>
#       <td>16494</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>14</td>
#       <td>16403</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>15</td>
#       <td>16257</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>16</td>
#       <td>16340</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>17</td>
#       <td>16363</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>18</td>
#       <td>16402</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>19</td>
#       <td>16388</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>20</td>
#       <td>16497</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>21</td>
#       <td>16379</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>22</td>
#       <td>16284</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>23</td>
#       <td>16287</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
interactions_by_day_part = (ad_events.groupby('day_part').size()
    .reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_day_part
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>day_part</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>night</td>
#       <td>114473</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>evening</td>
#       <td>98313</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>morning</td>
#       <td>98169</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>noon</td>
#       <td>81981</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
interactions_weekend = (ad_events.groupby(['Day_Of_Week', 'Is_weekend'])
    .size().reset_index(name='interaction_count')
)
avg_interactions = (interactions_weekend.groupby('Is_weekend')['interaction_count']
    .mean().round(2).reset_index(name='avg_interactions')
)
avg_interactions
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Is_weekend</th>
#       <th>avg_interactions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>56131.50</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>True</td>
#       <td>56136.67</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Campaign Engagement Relative to Campaign Duration

# %%
temp = ad_events.merge(ads[['ad_id', 'campaign_id']], on='ad_id')
temp = temp.merge(campaigns[['campaign_id', 'start_date', 'end_date', 'Duration (Days)']], on='campaign_id')

temp['during_campaign'] = (temp['timestamp'] >= temp['start_date']) & (temp['timestamp'] <= temp['end_date'])
temp['after_campaign'] = temp['timestamp'] > temp['end_date']

campaign_event_summary = temp.groupby(['campaign_id', 'Duration (Days)']).agg(events_during_campaign=('during_campaign', 'sum'),
    events_after_campaign=('after_campaign', 'sum')
).reset_index()
campaign_event_summary
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th
td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Interactions by Country

# %%
interactions_by_country = (ad_events.merge(users[['user_id', 'country']], on='user_id')
    .groupby('country').size().reset_index(name='interaction_count')
    .sort_values('interaction_count', ascending=False)
)
interactions_by_country
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>interaction_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9</th>
#       <td>United States</td>
#       <td>118467</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>United Kingdom</td>
#       <td>59321</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Canada</td>
#       <td>39459</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>India</td>
#       <td>36941</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Germany</td>
#       <td>32480</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>Australia</td>
#       <td>27900</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Brazil</td>
#       <td>24008</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Mexico</td>
#       <td>20128</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Japan</td>
#       <td>19291</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>France</td>
#       <td>14941</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Conversion Funnel: Impression → Click → Purchase

# %%
# Conversion funnel: Impression -> Click -> Purchase

event_counts = (
    ad_events['event_type']
    .value_counts()
    .reindex(['Impression', 'Click', 'Purchase'], fill_value=0)
)

impressions = event_counts['Impression']
clicks = event_counts['Click']
purchases = event_counts['Purchase']

conversion_funnel = pd.DataFrame({
    'metric': [
        'Total Impressions',
        'Clicks from Impressions',
        'Purchases from Clicks'
    ],
    'count': [
        impressions,
        clicks,
        purchases
    ],
    'percentage': [
        100,
        (clicks / impressions * 100) if impressions > 0 else 0,
        (purchases / clicks * 100) if clicks > 0 else 0
    ]
})

conversion_funnel['percentage'] = conversion_funnel['percentage'].round(2)

conversion_funnel
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>metric</th>
#       <th>count</th>
#       <th>percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Total Impressions</td>
#       <td>333841</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Clicks from Impressions</td>
#       <td>39345</td>
#       <td>11.79</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Purchases from Clicks</td>
#       <td>1989</td>
#       <td>5.06</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Average Events per User by Age Range and Gender

# %%
events_with_users = ad_events.merge(
    users[['user_id', 'age_range', 'user_gender']],
    on='user_id',
    how='left'
)

events_per_user = (
    events_with_users
    .groupby(['user_id', 'age_range', 'user_gender'])
    .size()
    .reset_index(name='events_count')
)

avg_events_by_age_gender = (
    events_per_user
    .groupby(['age_range', 'user_gender'])
    .agg(
        avg_events_per_user=('events_count', 'mean'),
        users_count=('user_id', 'count')
    )
    .reset_index()
    .round({'avg_events_per_user': 2})
)

avg_events_by_age_gender
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age_range</th>
#       <th>user_gender</th>
#       <th>avg_events_per_user</th>
#       <th>users_count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16-24</td>
#       <td>Female</td>
#       <td>39.59</td>
#       <td>1377</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>16-24</td>
#       <td>Male</td>
#       <td>39.65</td>
#       <td>2214</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>16-24</td>
#       <td>Other</td>
#       <td>39.54</td>
#       <td>385</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>25-34</td>
#       <td>Female</td>
#       <td>39.80</td>
#       <td>1397</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>25-34</td>
#       <td>Male</td>
#       <td>39.77</td>
#       <td>2255</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>25-34</td>
#       <td>Other</td>
#       <td>39.70</td>
#       <td>433</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>35-44</td>
#       <td>Female</td>
#       <td>39.17</td>
#       <td>499</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>35-44</td>
#       <td>Male</td>
#       <td>39.87</td>
#       <td>794</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>35-44</td>
#       <td>Other</td>
#       <td>39.72</td>
#       <td>141</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>45-65</td>
#       <td>Female</td>
#       <td>40.81</td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>45-65</td>
#       <td>Male</td>
#       <td>40.54</td>
#       <td>213</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>45-65</td>
#       <td>Other</td>
#       <td>39.76</td>
#       <td>45</td>
#     </tr>
#   </tbody>
# </table>
# </div>
